# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import torch.nn as nn
import torch
from tqdm.autonotebook import tqdm
import seaborn as sns
from Environments.igt import IGTEnv
from BasalGanglia.train import train
import pickle
from utils.utils import load_yaml
import math
from scipy.stats import t
import pandas as pd
import os
# Out:
# C:\Users\chari\AppData\Local\Temp\ipykernel_5400\1845841874.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# # Load Hyperarameters

# %%
params = load_yaml(os.path.join(os.getcwd(), r'hyperparams\IGT_hyperparams.yaml'))

# %%
TRAILS = params['TRAILS']
EPOCHS = params['EPOCHS'] 
NUM_BINS = params['NUM_BINS']
LR = params['LR'] #0.00075
NUM_ARMS = params['NUM_ARMS']
SCALING_FACTOR = params['SCALING_FACTOR']
REW_STD = params['REW_STD']
LOSS_STD = params['LOSS_STD']

# %% [markdown]
# ## Environment

# %%
env = IGTEnv(mean_reward=np.array([100,100,50,50])/SCALING_FACTOR,
             std_reward=np.array([REW_STD,REW_STD,REW_STD,REW_STD])/SCALING_FACTOR,
             mean_loss=np.array([-250,-1250,-50,-250])/SCALING_FACTOR,
             std_loss=np.array([LOSS_STD,LOSS_STD,LOSS_STD,LOSS_STD])/SCALING_FACTOR)

# %% [markdown]
# ## Training

# %%
reward_monitor, arm_chosen_monitor, avg_counts,ip_monitor, dp_monitor,ep_monitor= train(env, 
                                                      trails = TRAILS, 
                                                      epochs = EPOCHS, 
                                                      lr = LR, 
                                                      bins = NUM_BINS,
                                                      STN_data = None,
                                                      d1_amp=0.5,
                                                      d2_amp=0.1, 
                                                      gpi_threshold=0.15,
                                                      max_gpi_iters=50, 
                                                      del_lim=None, train_IP = False, 
                                                      del_med = None, printing = False,
                                                      gpi_mean= 1, ep_0 = 0.1,
                                                      alpha_ep = 0.001,
                                                      eta_ep = 0.1,
                                                      baseline_ep = 0.0, ep_lim=None)
# Out:
# Using Random noise
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7504], grad_fn=<RsubBackward1>), epsilon: 0.10090000182390213
# 1: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.10126283764839172
# 2: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2782]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2218], grad_fn=<RsubBackward1>), epsilon: 0.10155025124549866
# 3: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3147]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1853], grad_fn=<RsubBackward1>), epsilon: 0.10173939913511276
# 4: dp: tensor([[0.2500, 0.2505, 0.2505, 0.3568]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1432], grad_fn=<RsubBackward1>), epsilon: 0.10182318091392517
# 5: dp: tensor([[0.2500, 0.2505, 0.2505, 0.3978]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3978], grad_fn=<RsubBackward1>), epsilon: 0.10272135585546494
# 6: dp: tensor([[0.2500, 0.2505, 0.2505, 0.3807]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1193], grad_fn=<RsubBackward1>), epsilon: 0.10275138914585114
# 7: dp: tensor([[0.2500, 0.2505, 0.2505, 0.3662]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1338], grad_fn=<RsubBackward1>), epsilon: 0.10281256586313248
# 8: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3547]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1453], grad_fn=<RsubBackward1>), epsilon: 0.10290016978979111
# 9: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3460]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1540], grad_fn=<RsubBackward1>), epsilon: 0.10300838947296143
# 10: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3400]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1600], grad_fn=<RsubBackward1>), epsilon: 0.10313120484352112
# 11: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3364]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1636], grad_fn=<RsubBackward1>), epsilon: 0.10326289385557175
# 12: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3349]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1651], grad_fn=<RsubBackward1>), epsilon: 0.10339823365211487
# 13: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3352]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1648], grad_fn=<RsubBackward1>), epsilon: 0.10353255271911621
# 14: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3372]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3372], grad_fn=<RsubBackward1>), epsilon: 0.10442902147769928
# 15: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3222]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1778], grad_fn=<RsubBackward1>), epsilon: 0.10459569096565247
# 16: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3112]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1888], grad_fn=<RsubBackward1>), epsilon: 0.10479101538658142
# 17: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3037]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1963], grad_fn=<RsubBackward1>), epsilon: 0.10500592738389969
# 18: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2980]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2020], grad_fn=<RsubBackward1>), epsilon: 0.1052360087633133
# 19: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2939]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2061], grad_fn=<RsubBackward1>), epsilon: 0.10547689348459244
# 20: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2913]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2087], grad_fn=<RsubBackward1>), epsilon: 0.10572439432144165
# 21: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2903]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2097], grad_fn=<RsubBackward1>), epsilon: 0.10597458481788635
# 22: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2905]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2095], grad_fn=<RsubBackward1>), epsilon: 0.10622382164001465
# 23: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2920]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2080], grad_fn=<RsubBackward1>), epsilon: 0.10646877437829971
# 24: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2946]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2054], grad_fn=<RsubBackward1>), epsilon: 0.10670645534992218
# 25: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2982]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2018], grad_fn=<RsubBackward1>), epsilon: 0.10693421959877014
# 26: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3028]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1972], grad_fn=<RsubBackward1>), epsilon: 0.10714954882860184
# 27: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3082]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3082], grad_fn=<RsubBackward1>), epsilon: 0.1080423966050148
# 28: dp: tensor([[0.2500, 0.2504, 0.2504, 0.3004]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1996], grad_fn=<RsubBackward1>), epsilon: 0.1082630455493927
# 29: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2945]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2055], grad_fn=<RsubBackward1>), epsilon: 0.10849934816360474
# 30: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2901]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2099], grad_fn=<RsubBackward1>), epsilon: 0.10874713957309723
# 31: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2873]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2873], grad_fn=<RsubBackward1>), epsilon: 0.10963839292526245
# 32: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2742]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2258], grad_fn=<RsubBackward1>), epsilon: 0.10992813855409622
# 33: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2633]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2367], grad_fn=<RsubBackward1>), epsilon: 0.11024710536003113
# 34: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2575]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11113325506448746
# 35: dp: tensor([[0.2584, 0.2504, 0.2504, 0.2547]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7584], grad_fn=<RsubBackward1>), epsilon: 0.11202212423086166
# 36: dp: tensor([[0.2500, 0.2504, 0.2504, 0.2521]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7504], grad_fn=<RsubBackward1>), epsilon: 0.11291009932756424
# 37: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11379358172416687
# 38: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11467618495225906
# 39: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2504], grad_fn=<RsubBackward1>), epsilon: 0.11502724885940552
# 40: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11590861529111862
# 41: dp: tensor([[0.2508, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7508], grad_fn=<RsubBackward1>), epsilon: 0.1167927086353302
# 42: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.11714065819978714
# 43: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.11748825758695602
# 44: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2500], grad_fn=<RsubBackward1>), epsilon: 0.11783550679683685
# 45: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.11818241328001022
# 46: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2508]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11906062066555023
# 47: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2515]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.1199379563331604
# 48: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2522]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2478], grad_fn=<RsubBackward1>), epsilon: 0.12027693539857864
# 49: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2542]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.12115304917097092
# 50: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2561]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2439], grad_fn=<RsubBackward1>), epsilon: 0.1214803159236908
# 51: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2592]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2408], grad_fn=<RsubBackward1>), epsilon: 0.1217987909913063
# 52: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2635]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2365], grad_fn=<RsubBackward1>), epsilon: 0.12210536003112793
# 53: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2688]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2312], grad_fn=<RsubBackward1>), epsilon: 0.12239725887775421
# 54: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2750]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2250], grad_fn=<RsubBackward1>), epsilon: 0.12267207354307175
# 55: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2820]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2180], grad_fn=<RsubBackward1>), epsilon: 0.1229277029633522
# 56: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2897]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2103], grad_fn=<RsubBackward1>), epsilon: 0.12316219508647919
# 57: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2981]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2981], grad_fn=<RsubBackward1>), epsilon: 0.12403903156518936
# 58: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2918]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2082], grad_fn=<RsubBackward1>), epsilon: 0.12426670640707016
# 59: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2877]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2123], grad_fn=<RsubBackward1>), epsilon: 0.12450525909662247
# 60: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2851]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2149], grad_fn=<RsubBackward1>), epsilon: 0.12475055456161499
# 61: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2840]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2160], grad_fn=<RsubBackward1>), epsilon: 0.12499872595071793
# 62: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2841]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2159], grad_fn=<RsubBackward1>), epsilon: 0.12524619698524475
# 63: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2855]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2855], grad_fn=<RsubBackward1>), epsilon: 0.12612095475196838
# 64: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2748]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2252], grad_fn=<RsubBackward1>), epsilon: 0.12639275193214417
# 65: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2661]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2339], grad_fn=<RsubBackward1>), epsilon: 0.1266876459121704
# 66: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2596]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2404], grad_fn=<RsubBackward1>), epsilon: 0.12700000405311584
# 67: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2549]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2451], grad_fn=<RsubBackward1>), epsilon: 0.12732456624507904
# 68: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2521]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.12766197323799133
# 69: dp: tensor([[0.2500, 0.2500, 0.2656, 0.2508]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2344], grad_fn=<RsubBackward1>), epsilon: 0.12795715034008026
# 70: dp: tensor([[0.2500, 0.2500, 0.2923, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2923], grad_fn=<RsubBackward1>), epsilon: 0.1284037083387375
# 71: dp: tensor([[0.2500, 0.2500, 0.2978, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2022], grad_fn=<RsubBackward1>), epsilon: 0.12861087918281555
# 72: dp: tensor([[0.2500, 0.2500, 0.3121, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.1879], grad_fn=<RsubBackward1>), epsilon: 0.12877966463565826
# 73: dp: tensor([[0.2500, 0.2500, 0.3323, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.3323], grad_fn=<RsubBackward1>), epsilon: 0.12931938469409943
# 74: dp: tensor([[0.2500, 0.2500, 0.3362, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.1638], grad_fn=<RsubBackward1>), epsilon: 0.12942548096179962
# 75: dp: tensor([[0.2500, 0.2500, 0.3452, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.3452], grad_fn=<RsubBackward1>), epsilon: 0.12999236583709717
# 76: dp: tensor([[0.2500, 0.2500, 0.3420, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.3420], grad_fn=<RsubBackward1>), epsilon: 0.13055196404457092
# 77: dp: tensor([[0.2500, 0.2500, 0.3290, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.1710], grad_fn=<RsubBackward1>), epsilon: 0.1306750476360321
# 78: dp: tensor([[0.2500, 0.2500, 0.3225, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.1775], grad_fn=<RsubBackward1>), epsilon: 0.13081476092338562
# 79: dp: tensor([[0.2500, 0.2500, 0.3224, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.3224], grad_fn=<RsubBackward1>), epsilon: 0.131330206990242
# 80: dp: tensor([[0.2500, 0.2500, 0.3122, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.1878], grad_fn=<RsubBackward1>), epsilon: 0.13149598240852356
# 81: dp: tensor([[0.2500, 0.2500, 0.3091, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.1909], grad_fn=<RsubBackward1>), epsilon: 0.13166986405849457
# 82: dp: tensor([[0.2500, 0.2500, 0.3124, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.1876], grad_fn=<RsubBackward1>), epsilon: 0.13183486461639404
# 83: dp: tensor([[0.2500, 0.2500, 0.3211, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.3211], grad_fn=<RsubBackward1>), epsilon: 0.13234631717205048
# 84: dp: tensor([[0.2500, 0.2500, 0.3193, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.3193], grad_fn=<RsubBackward1>), epsilon: 0.13285312056541443
# 85: dp: tensor([[0.2500, 0.2500, 0.3086, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.3086], grad_fn=<RsubBackward1>), epsilon: 0.13333454728126526
# 86: dp: tensor([[0.2500, 0.2500, 0.2903, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2097], grad_fn=<RsubBackward1>), epsilon: 0.13355712592601776
# 87: dp: tensor([[0.2500, 0.2500, 0.2798, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2202], grad_fn=<RsubBackward1>), epsilon: 0.1338077038526535
# 88: dp: tensor([[0.2500, 0.2500, 0.2771, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2771], grad_fn=<RsubBackward1>), epsilon: 0.134210005402565
# 89: dp: tensor([[0.2500, 0.2500, 0.2666, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2666], grad_fn=<RsubBackward1>), epsilon: 0.13458441197872162
# 90: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.1349145621061325
# 91: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2513]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.13577604293823242
# 92: dp: tensor([[0.2581, 0.2500, 0.2500, 0.2525]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7419], grad_fn=<RsubBackward1>), epsilon: 0.13663619756698608
# 93: dp: tensor([[0.2732, 0.2500, 0.2500, 0.2536]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7268], grad_fn=<RsubBackward1>), epsilon: 0.13749447464942932
# 94: dp: tensor([[0.2938, 0.2500, 0.2500, 0.2545]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7938], grad_fn=<RsubBackward1>), epsilon: 0.1383569836616516
# 95: dp: tensor([[0.2943, 0.2500, 0.2500, 0.2554]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7943], grad_fn=<RsubBackward1>), epsilon: 0.13921862840652466
# 96: dp: tensor([[0.2800, 0.2500, 0.2500, 0.2562]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7200], grad_fn=<RsubBackward1>), epsilon: 0.14007380604743958
# 97: dp: tensor([[0.2731, 0.2500, 0.2500, 0.2569]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7269], grad_fn=<RsubBackward1>), epsilon: 0.14092865586280823
# 98: dp: tensor([[0.2730, 0.2500, 0.2500, 0.2576]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7730], grad_fn=<RsubBackward1>), epsilon: 0.14178772270679474
# 99: dp: tensor([[0.2592, 0.2500, 0.2500, 0.2582]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7592], grad_fn=<RsubBackward1>), epsilon: 0.1426459401845932
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7496], grad_fn=<RsubBackward1>), epsilon: 0.10089637339115143
# 1: dp: tensor([[0.2504, 0.2937, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7063], grad_fn=<RsubBackward1>), epsilon: 0.10178866237401962
# 2: dp: tensor([[0.2505, 0.3417, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6583], grad_fn=<RsubBackward1>), epsilon: 0.10267375409603119
# 3: dp: tensor([[0.2505, 0.3884, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6116], grad_fn=<RsubBackward1>), epsilon: 0.10354732722043991
# 4: dp: tensor([[0.2506, 0.4267, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5733], grad_fn=<RsubBackward1>), epsilon: 0.10440640896558762
# 5: dp: tensor([[0.2506, 0.4535, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5465], grad_fn=<RsubBackward1>), epsilon: 0.10525154322385788
# 6: dp: tensor([[0.2506, 0.4705, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5295], grad_fn=<RsubBackward1>), epsilon: 0.10608568042516708
# 7: dp: tensor([[0.2506, 0.4809, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9809], grad_fn=<RsubBackward1>), epsilon: 0.10697959363460541
# 8: dp: tensor([[0.2506, 0.4803, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5197], grad_fn=<RsubBackward1>), epsilon: 0.10780549794435501
# 9: dp: tensor([[0.2506, 0.4798, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5202], grad_fn=<RsubBackward1>), epsilon: 0.10863087326288223
# 10: dp: tensor([[0.2506, 0.4796, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9796], grad_fn=<RsubBackward1>), epsilon: 0.109522245824337
# 11: dp: tensor([[0.2506, 0.4758, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5242], grad_fn=<RsubBackward1>), epsilon: 0.1103486493229866
# 12: dp: tensor([[0.2506, 0.4720, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5280], grad_fn=<RsubBackward1>), epsilon: 0.11117671430110931
# 13: dp: tensor([[0.2506, 0.4685, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5315], grad_fn=<RsubBackward1>), epsilon: 0.11200622469186783
# 14: dp: tensor([[0.2506, 0.4653, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5347], grad_fn=<RsubBackward1>), epsilon: 0.11283687502145767
# 15: dp: tensor([[0.2506, 0.4627, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5373], grad_fn=<RsubBackward1>), epsilon: 0.11366831511259079
# 16: dp: tensor([[0.2506, 0.4606, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5394], grad_fn=<RsubBackward1>), epsilon: 0.11450014263391495
# 17: dp: tensor([[0.2506, 0.4592, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5408], grad_fn=<RsubBackward1>), epsilon: 0.11533196270465851
# 18: dp: tensor([[0.2506, 0.4585, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5415], grad_fn=<RsubBackward1>), epsilon: 0.11616336554288864
# 19: dp: tensor([[0.2506, 0.4584, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5416], grad_fn=<RsubBackward1>), epsilon: 0.1169939711689949
# 20: dp: tensor([[0.2506, 0.4590, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5410], grad_fn=<RsubBackward1>), epsilon: 0.11782343685626984
# 21: dp: tensor([[0.2506, 0.4600, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5400], grad_fn=<RsubBackward1>), epsilon: 0.11865145713090897
# 22: dp: tensor([[0.2506, 0.4615, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9615], grad_fn=<RsubBackward1>), epsilon: 0.11953280866146088
# 23: dp: tensor([[0.2506, 0.4542, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5458], grad_fn=<RsubBackward1>), epsilon: 0.12036240845918655
# 24: dp: tensor([[0.2506, 0.4471, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5529], grad_fn=<RsubBackward1>), epsilon: 0.1211949959397316
# 25: dp: tensor([[0.2506, 0.4406, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5594], grad_fn=<RsubBackward1>), epsilon: 0.12203006446361542
# 26: dp: tensor([[0.2506, 0.4349, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5651], grad_fn=<RsubBackward1>), epsilon: 0.12286701053380966
# 27: dp: tensor([[0.2506, 0.4303, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5697], grad_fn=<RsubBackward1>), epsilon: 0.123705193400383
# 28: dp: tensor([[0.2506, 0.4270, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5730], grad_fn=<RsubBackward1>), epsilon: 0.12454396486282349
# 29: dp: tensor([[0.2506, 0.4252, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5748], grad_fn=<RsubBackward1>), epsilon: 0.1253826916217804
# 30: dp: tensor([[0.2506, 0.4247, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5753], grad_fn=<RsubBackward1>), epsilon: 0.12622079253196716
# 31: dp: tensor([[0.2506, 0.4255, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5745], grad_fn=<RsubBackward1>), epsilon: 0.12705771625041962
# 32: dp: tensor([[0.2506, 0.4274, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5726], grad_fn=<RsubBackward1>), epsilon: 0.12789297103881836
# 33: dp: tensor([[0.2506, 0.4303, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9303], grad_fn=<RsubBackward1>), epsilon: 0.1287650763988495
# 34: dp: tensor([[0.2506, 0.4163, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5837], grad_fn=<RsubBackward1>), epsilon: 0.12960317730903625
# 35: dp: tensor([[0.2506, 0.4029, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5971], grad_fn=<RsubBackward1>), epsilon: 0.13044528663158417
# 36: dp: tensor([[0.2506, 0.3908, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6092], grad_fn=<RsubBackward1>), epsilon: 0.13129039108753204
# 37: dp: tensor([[0.2506, 0.3807, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6193], grad_fn=<RsubBackward1>), epsilon: 0.13213752210140228
# 38: dp: tensor([[0.2506, 0.3727, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6273], grad_fn=<RsubBackward1>), epsilon: 0.13298583030700684
# 39: dp: tensor([[0.2506, 0.3672, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6328], grad_fn=<RsubBackward1>), epsilon: 0.1338346153497696
# 40: dp: tensor([[0.2506, 0.3640, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6360], grad_fn=<RsubBackward1>), epsilon: 0.1346832662820816
# 41: dp: tensor([[0.2506, 0.3632, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6368], grad_fn=<RsubBackward1>), epsilon: 0.1355312615633011
# 42: dp: tensor([[0.2506, 0.3644, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6356], grad_fn=<RsubBackward1>), epsilon: 0.13637812435626984
# 43: dp: tensor([[0.2506, 0.3676, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6324], grad_fn=<RsubBackward1>), epsilon: 0.13722340762615204
# 44: dp: tensor([[0.2506, 0.3725, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6275], grad_fn=<RsubBackward1>), epsilon: 0.13806669414043427
# 45: dp: tensor([[0.2506, 0.3787, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.8787], grad_fn=<RsubBackward1>), epsilon: 0.13892862200737
# 46: dp: tensor([[0.2506, 0.3583, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6417], grad_fn=<RsubBackward1>), epsilon: 0.139773428440094
# 47: dp: tensor([[0.2505, 0.3401, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6599], grad_fn=<RsubBackward1>), epsilon: 0.14062081277370453
# 48: dp: tensor([[0.2505, 0.3249, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6751], grad_fn=<RsubBackward1>), epsilon: 0.14146971702575684
# 49: dp: tensor([[0.2505, 0.3127, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6873], grad_fn=<RsubBackward1>), epsilon: 0.14231936633586884
# 50: dp: tensor([[0.2505, 0.3035, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6965], grad_fn=<RsubBackward1>), epsilon: 0.14316922426223755
# 51: dp: tensor([[0.2505, 0.2971, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7029], grad_fn=<RsubBackward1>), epsilon: 0.14401890337467194
# 52: dp: tensor([[0.2505, 0.2932, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7068], grad_fn=<RsubBackward1>), epsilon: 0.14486812055110931
# 53: dp: tensor([[0.2505, 0.2916, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7084], grad_fn=<RsubBackward1>), epsilon: 0.14571663737297058
# 54: dp: tensor([[0.2505, 0.2920, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7080], grad_fn=<RsubBackward1>), epsilon: 0.14656426012516022
# 55: dp: tensor([[0.2505, 0.2943, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7057], grad_fn=<RsubBackward1>), epsilon: 0.1474108248949051
# 56: dp: tensor([[0.2505, 0.2982, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7018], grad_fn=<RsubBackward1>), epsilon: 0.14825615286827087
# 57: dp: tensor([[0.2505, 0.3035, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6965], grad_fn=<RsubBackward1>), epsilon: 0.14910008013248444
# 58: dp: tensor([[0.2505, 0.3102, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.8102], grad_fn=<RsubBackward1>), epsilon: 0.14995098114013672
# 59: dp: tensor([[0.2505, 0.2907, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7093], grad_fn=<RsubBackward1>), epsilon: 0.15079450607299805
# 60: dp: tensor([[0.2505, 0.2751, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7249], grad_fn=<RsubBackward1>), epsilon: 0.15163849294185638
# 61: dp: tensor([[0.2504, 0.2635, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7365], grad_fn=<RsubBackward1>), epsilon: 0.15248245000839233
# 62: dp: tensor([[0.2504, 0.2608, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7392], grad_fn=<RsubBackward1>), epsilon: 0.15332572162151337
# 63: dp: tensor([[0.2504, 0.2589, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7589], grad_fn=<RsubBackward1>), epsilon: 0.1541723906993866
# 64: dp: tensor([[0.2504, 0.2516, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.154481902718544
# 65: dp: tensor([[0.2504, 0.2500, 0.2504, 0.2805]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2805], grad_fn=<RsubBackward1>), epsilon: 0.1553274244070053
# 66: dp: tensor([[0.2504, 0.2500, 0.2504, 0.2534]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2466], grad_fn=<RsubBackward1>), epsilon: 0.15562763810157776
# 67: dp: tensor([[0.2504, 0.2500, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.15593674778938293
# 68: dp: tensor([[0.2504, 0.2500, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.15677720308303833
# 69: dp: tensor([[0.2504, 0.2500, 0.2504, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2504], grad_fn=<RsubBackward1>), epsilon: 0.15708616375923157
# 70: dp: tensor([[0.2504, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.15739381313323975
# 71: dp: tensor([[0.2504, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7504], grad_fn=<RsubBackward1>), epsilon: 0.15823641419410706
# 72: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.1585429161787033
# 73: dp: tensor([[0.2500, 0.2500, 0.2560, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2560], grad_fn=<RsubBackward1>), epsilon: 0.15886513888835907
# 74: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.15970267355442047
# 75: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.16000771522521973
# 76: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.1608441025018692
# 77: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7500], grad_fn=<RsubBackward1>), epsilon: 0.16168326139450073
# 78: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.1619863212108612
# 79: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2523]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2477], grad_fn=<RsubBackward1>), epsilon: 0.162282794713974
# 80: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2579]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2421], grad_fn=<RsubBackward1>), epsilon: 0.1625639945268631
# 81: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2663]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2337], grad_fn=<RsubBackward1>), epsilon: 0.16282229125499725
# 82: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2770]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2230], grad_fn=<RsubBackward1>), epsilon: 0.16305121779441833
# 83: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2896]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2896], grad_fn=<RsubBackward1>), epsilon: 0.16388817131519318
# 84: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2754]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2246], grad_fn=<RsubBackward1>), epsilon: 0.16412045061588287
# 85: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2647]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2353], grad_fn=<RsubBackward1>), epsilon: 0.16438156366348267
# 86: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2574]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2500], grad_fn=<RsubBackward1>), epsilon: 0.16468192636966705
# 87: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2507]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2493], grad_fn=<RsubBackward1>), epsilon: 0.1649799942970276
# 88: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.16581140458583832
# 89: dp: tensor([[0.2510, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7510], grad_fn=<RsubBackward1>), epsilon: 0.1666455864906311
# 90: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.16747532784938812
# 91: dp: tensor([[0.2500, 0.2501, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.16830424964427948
# 92: dp: tensor([[0.2500, 0.2502, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7500], grad_fn=<RsubBackward1>), epsilon: 0.1691359430551529
# 93: dp: tensor([[0.2500, 0.2502, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7498], grad_fn=<RsubBackward1>), epsilon: 0.16996318101882935
# 94: dp: tensor([[0.2500, 0.2513, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7487], grad_fn=<RsubBackward1>), epsilon: 0.17078953981399536
# 95: dp: tensor([[0.2500, 0.2534, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7500], grad_fn=<RsubBackward1>), epsilon: 0.1716187447309494
# 96: dp: tensor([[0.2500, 0.2552, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.17191186547279358
# 97: dp: tensor([[0.2500, 0.2569, 0.2594, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7431], grad_fn=<RsubBackward1>), epsilon: 0.17273595929145813
# 98: dp: tensor([[0.2500, 0.2595, 0.2679, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2679], grad_fn=<RsubBackward1>), epsilon: 0.17307539284229279
# 99: dp: tensor([[0.2500, 0.2618, 0.2592, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7618], grad_fn=<RsubBackward1>), epsilon: 0.17390231788158417
# 0: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.10036373138427734
# 1: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2937]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2063], grad_fn=<RsubBackward1>), epsilon: 0.10061009228229523
# 2: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3416]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1584], grad_fn=<RsubBackward1>), epsilon: 0.10073145478963852
# 3: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3877]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1123], grad_fn=<RsubBackward1>), epsilon: 0.1007491871714592
# 4: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4246]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0754], grad_fn=<RsubBackward1>), epsilon: 0.10070374608039856
# 5: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4499]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0501], grad_fn=<RsubBackward1>), epsilon: 0.1006278544664383
# 6: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4660]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0340], grad_fn=<RsubBackward1>), epsilon: 0.1005387157201767
# 7: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4762]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0238], grad_fn=<RsubBackward1>), epsilon: 0.10044384002685547
# 8: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4827]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4827], grad_fn=<RsubBackward1>), epsilon: 0.10134339332580566
# 9: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4822]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0178], grad_fn=<RsubBackward1>), epsilon: 0.1012452095746994
# 10: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4818]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0182], grad_fn=<RsubBackward1>), epsilon: 0.10114727914333344
# 11: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4814]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0186], grad_fn=<RsubBackward1>), epsilon: 0.10104958713054657
# 12: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4811]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4811], grad_fn=<RsubBackward1>), epsilon: 0.10194853693246841
# 13: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4776]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0224], grad_fn=<RsubBackward1>), epsilon: 0.10185158997774124
# 14: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4740]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0260], grad_fn=<RsubBackward1>), epsilon: 0.10175648331642151
# 15: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4703]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0297], grad_fn=<RsubBackward1>), epsilon: 0.1016635000705719
# 16: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4667]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0333], grad_fn=<RsubBackward1>), epsilon: 0.10157288610935211
# 17: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4631]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0369], grad_fn=<RsubBackward1>), epsilon: 0.10148480534553528
# 18: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4598]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0402], grad_fn=<RsubBackward1>), epsilon: 0.10139932483434677
# 19: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4568]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0432], grad_fn=<RsubBackward1>), epsilon: 0.10131639987230301
# 20: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4542]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0458], grad_fn=<RsubBackward1>), epsilon: 0.10123586654663086
# 21: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4520]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0480], grad_fn=<RsubBackward1>), epsilon: 0.10115743428468704
# 22: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4503]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0497], grad_fn=<RsubBackward1>), epsilon: 0.10108071565628052
# 23: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4490]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0510], grad_fn=<RsubBackward1>), epsilon: 0.10100526362657547
# 24: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4484]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0516], grad_fn=<RsubBackward1>), epsilon: 0.1009305790066719
# 25: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4482]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0518], grad_fn=<RsubBackward1>), epsilon: 0.10085615515708923
# 26: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4484]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0516], grad_fn=<RsubBackward1>), epsilon: 0.10078153014183044
# 27: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4491]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0509], grad_fn=<RsubBackward1>), epsilon: 0.10070628672838211
# 28: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4502]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.4502], grad_fn=<RsubBackward1>), epsilon: 0.10160557925701141
# 29: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4386]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0614], grad_fn=<RsubBackward1>), epsilon: 0.10154098272323608
# 30: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4266]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0734], grad_fn=<RsubBackward1>), epsilon: 0.10149191319942474
# 31: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4148]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0852], grad_fn=<RsubBackward1>), epsilon: 0.10146036744117737
# 32: dp: tensor([[0.2506, 0.2506, 0.2506, 0.4041]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.0959], grad_fn=<RsubBackward1>), epsilon: 0.10144682973623276
# 33: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3949]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1051], grad_fn=<RsubBackward1>), epsilon: 0.10145001113414764
# 34: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3878]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1122], grad_fn=<RsubBackward1>), epsilon: 0.10146693885326385
# 35: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3830]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1170], grad_fn=<RsubBackward1>), epsilon: 0.10149340331554413
# 36: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3807]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1193], grad_fn=<RsubBackward1>), epsilon: 0.10152453184127808
# 37: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3808]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1192], grad_fn=<RsubBackward1>), epsilon: 0.10155537724494934
# 38: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3831]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3831], grad_fn=<RsubBackward1>), epsilon: 0.1024538204073906
# 39: dp: tensor([[0.2506, 0.2506, 0.2506, 0.3593]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1407], grad_fn=<RsubBackward1>), epsilon: 0.10253088176250458
# 40: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3379]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1621], grad_fn=<RsubBackward1>), epsilon: 0.1026594340801239
# 41: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3200]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1800], grad_fn=<RsubBackward1>), epsilon: 0.10283342748880386
# 42: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3063]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1937], grad_fn=<RsubBackward1>), epsilon: 0.10304347425699234
# 43: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2967]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2033], grad_fn=<RsubBackward1>), epsilon: 0.10327908396720886
# 44: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2909]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2091], grad_fn=<RsubBackward1>), epsilon: 0.10352996736764908
# 45: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2887]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2113], grad_fn=<RsubBackward1>), epsilon: 0.10378667712211609
# 46: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2895]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2105], grad_fn=<RsubBackward1>), epsilon: 0.10404077917337418
# 47: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2931]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2069], grad_fn=<RsubBackward1>), epsilon: 0.1042848452925682
# 48: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2992]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2008], grad_fn=<RsubBackward1>), epsilon: 0.10451243072748184
# 49: dp: tensor([[0.2505, 0.2505, 0.2505, 0.3073]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3073], grad_fn=<RsubBackward1>), epsilon: 0.10540791600942612
# 50: dp: tensor([[0.2505, 0.2505, 0.2505, 0.2896]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2104], grad_fn=<RsubBackward1>), epsilon: 0.105660080909729
# 51: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2764]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2236], grad_fn=<RsubBackward1>), epsilon: 0.10594790428876877
# 52: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2671]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2329], grad_fn=<RsubBackward1>), epsilon: 0.1062607392668724
# 53: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2653]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2347], grad_fn=<RsubBackward1>), epsilon: 0.10657797753810883
# 54: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2645]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2355], grad_fn=<RsubBackward1>), epsilon: 0.10689710080623627
# 55: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2645]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2645], grad_fn=<RsubBackward1>), epsilon: 0.10779020190238953
# 56: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2590]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2410], grad_fn=<RsubBackward1>), epsilon: 0.10812307894229889
# 57: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2545]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2455], grad_fn=<RsubBackward1>), epsilon: 0.10846749693155289
# 58: dp: tensor([[0.2504, 0.2504, 0.2504, 0.2512]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.108822762966156
# 59: dp: tensor([[0.2504, 0.2504, 0.2787, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2787], grad_fn=<RsubBackward1>), epsilon: 0.10925402492284775
# 60: dp: tensor([[0.2504, 0.2504, 0.2749, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2749], grad_fn=<RsubBackward1>), epsilon: 0.10967496782541275
# 61: dp: tensor([[0.2504, 0.2504, 0.2550, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2550], grad_fn=<RsubBackward1>), epsilon: 0.11004336923360825
# 62: dp: tensor([[0.2504, 0.2504, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7504], grad_fn=<RsubBackward1>), epsilon: 0.1109333261847496
# 63: dp: tensor([[0.2504, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11181878298521042
# 64: dp: tensor([[0.2504, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.1121717020869255
# 65: dp: tensor([[0.2504, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11305592209100723
# 66: dp: tensor([[0.2504, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7496], grad_fn=<RsubBackward1>), epsilon: 0.11393924057483673
# 67: dp: tensor([[0.2804, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7804], grad_fn=<RsubBackward1>), epsilon: 0.1148253008723259
# 68: dp: tensor([[0.2634, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7366], grad_fn=<RsubBackward1>), epsilon: 0.11570607870817184
# 69: dp: tensor([[0.2598, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7598], grad_fn=<RsubBackward1>), epsilon: 0.11659037321805954
# 70: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2500], grad_fn=<RsubBackward1>), epsilon: 0.1169385239481926
# 71: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11781797558069229
# 72: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7500], grad_fn=<RsubBackward1>), epsilon: 0.11870015412569046
# 73: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7500], grad_fn=<RsubBackward1>), epsilon: 0.11957784742116928
# 74: dp: tensor([[0.2500, 0.2500, 0.2500, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2500], grad_fn=<RsubBackward1>), epsilon: 0.11992301046848297
# 75: dp: tensor([[0.2500, 0.2500, 0.2517, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2483], grad_fn=<RsubBackward1>), epsilon: 0.12026332318782806
# 76: dp: tensor([[0.2500, 0.2500, 0.2641, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.2641], grad_fn=<RsubBackward1>), epsilon: 0.12064532935619354
# 77: dp: tensor([[0.2500, 0.2500, 0.2637, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2363], grad_fn=<RsubBackward1>), epsilon: 0.12095259130001068
# 78: dp: tensor([[0.2500, 0.2500, 0.2728, 0.2500]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([0.2272], grad_fn=<RsubBackward1>), epsilon: 0.12123491615056992
# ...
# 7: dp: tensor([[0.2506, 0.4385, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5615], grad_fn=<RsubBackward1>), epsilon: 0.10700157284736633
# 8: dp: tensor([[0.2506, 0.4326, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5674], grad_fn=<RsubBackward1>), epsilon: 0.10785458981990814
# 9: dp: tensor([[0.2506, 0.4280, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5720], grad_fn=<RsubBackward1>), epsilon: 0.10870878398418427
# 10: dp: tensor([[0.2505, 0.4249, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5751], grad_fn=<RsubBackward1>), epsilon: 0.10956346243619919
# 11: dp: tensor([[0.2505, 0.4232, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5768], grad_fn=<RsubBackward1>), epsilon: 0.11041799187660217
# 12: dp: tensor([[0.2505, 0.4229, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5771], grad_fn=<RsubBackward1>), epsilon: 0.11127180606126785
# 13: dp: tensor([[0.2505, 0.4238, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5762], grad_fn=<RsubBackward1>), epsilon: 0.11212439090013504
# 14: dp: tensor([[0.2506, 0.4257, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5743], grad_fn=<RsubBackward1>), epsilon: 0.11297529935836792
# 15: dp: tensor([[0.2506, 0.4286, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5714], grad_fn=<RsubBackward1>), epsilon: 0.11382413655519485
# 16: dp: tensor([[0.2506, 0.4321, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5679], grad_fn=<RsubBackward1>), epsilon: 0.11467056721448898
# 17: dp: tensor([[0.2506, 0.4361, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5639], grad_fn=<RsubBackward1>), epsilon: 0.11551432311534882
# 18: dp: tensor([[0.2506, 0.4403, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5597], grad_fn=<RsubBackward1>), epsilon: 0.11635518819093704
# 19: dp: tensor([[0.2506, 0.4447, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9447], grad_fn=<RsubBackward1>), epsilon: 0.1172388345003128
# 20: dp: tensor([[0.2506, 0.4369, 0.2506, 0.2506]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.9369], grad_fn=<RsubBackward1>), epsilon: 0.11812159419059753
# 21: dp: tensor([[0.2505, 0.4198, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5802], grad_fn=<RsubBackward1>), epsilon: 0.11896894872188568
# 22: dp: tensor([[0.2505, 0.4023, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.5977], grad_fn=<RsubBackward1>), epsilon: 0.11982188373804092
# 23: dp: tensor([[0.2505, 0.3856, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6144], grad_fn=<RsubBackward1>), epsilon: 0.12067913264036179
# 24: dp: tensor([[0.2505, 0.3704, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6296], grad_fn=<RsubBackward1>), epsilon: 0.12153946608304977
# 25: dp: tensor([[0.2505, 0.3574, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6426], grad_fn=<RsubBackward1>), epsilon: 0.12240184098482132
# 26: dp: tensor([[0.2505, 0.3468, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6532], grad_fn=<RsubBackward1>), epsilon: 0.12326541543006897
# 27: dp: tensor([[0.2505, 0.3387, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6613], grad_fn=<RsubBackward1>), epsilon: 0.12412954866886139
# 28: dp: tensor([[0.2505, 0.3329, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6671], grad_fn=<RsubBackward1>), epsilon: 0.12499374896287918
# 29: dp: tensor([[0.2505, 0.3293, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6707], grad_fn=<RsubBackward1>), epsilon: 0.1258576214313507
# 30: dp: tensor([[0.2505, 0.3277, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6723], grad_fn=<RsubBackward1>), epsilon: 0.1267208755016327
# 31: dp: tensor([[0.2505, 0.3280, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6720], grad_fn=<RsubBackward1>), epsilon: 0.12758322060108185
# 32: dp: tensor([[0.2505, 0.3300, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6700], grad_fn=<RsubBackward1>), epsilon: 0.12844440340995789
# 33: dp: tensor([[0.2505, 0.3335, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6665], grad_fn=<RsubBackward1>), epsilon: 0.1293041855096817
# 34: dp: tensor([[0.2505, 0.3385, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6615], grad_fn=<RsubBackward1>), epsilon: 0.130162313580513
# 35: dp: tensor([[0.2505, 0.3447, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6553], grad_fn=<RsubBackward1>), epsilon: 0.1310185045003891
# 36: dp: tensor([[0.2505, 0.3520, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.8520], grad_fn=<RsubBackward1>), epsilon: 0.13188748061656952
# 37: dp: tensor([[0.2505, 0.3350, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6650], grad_fn=<RsubBackward1>), epsilon: 0.13274359703063965
# 38: dp: tensor([[0.2505, 0.3207, 0.2505, 0.2505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6793], grad_fn=<RsubBackward1>), epsilon: 0.13360095024108887
# 39: dp: tensor([[0.2504, 0.3092, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6908], grad_fn=<RsubBackward1>), epsilon: 0.13445888459682465
# 40: dp: tensor([[0.2504, 0.3003, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.6997], grad_fn=<RsubBackward1>), epsilon: 0.13531695306301117
# 41: dp: tensor([[0.2504, 0.2936, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7064], grad_fn=<RsubBackward1>), epsilon: 0.13617482781410217
# 42: dp: tensor([[0.2504, 0.2889, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7111], grad_fn=<RsubBackward1>), epsilon: 0.13703228533267975
# 43: dp: tensor([[0.2504, 0.2860, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7140], grad_fn=<RsubBackward1>), epsilon: 0.13788914680480957
# 44: dp: tensor([[0.2504, 0.2845, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7155], grad_fn=<RsubBackward1>), epsilon: 0.1387452781200409
# 45: dp: tensor([[0.2504, 0.2844, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7156], grad_fn=<RsubBackward1>), epsilon: 0.13960056006908417
# 46: dp: tensor([[0.2504, 0.2854, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-11.7854], grad_fn=<RsubBackward1>), epsilon: 0.14046095311641693
# 47: dp: tensor([[0.2504, 0.2710, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7290], grad_fn=<RsubBackward1>), epsilon: 0.14131556451320648
# 48: dp: tensor([[0.2504, 0.2624, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7376], grad_fn=<RsubBackward1>), epsilon: 0.14216990768909454
# 49: dp: tensor([[0.2504, 0.2589, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7411], grad_fn=<RsubBackward1>), epsilon: 0.14302362501621246
# 50: dp: tensor([[0.2504, 0.2561, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.7439], grad_fn=<RsubBackward1>), epsilon: 0.14387665688991547
# 51: dp: tensor([[0.2504, 0.2539, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7496], grad_fn=<RsubBackward1>), epsilon: 0.1447291523218155
# 52: dp: tensor([[0.2771, 0.2519, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7771], grad_fn=<RsubBackward1>), epsilon: 0.14558441936969757
# 53: dp: tensor([[0.2619, 0.2501, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([0.7381], grad_fn=<RsubBackward1>), epsilon: 0.14643453061580658
# 54: dp: tensor([[0.2587, 0.2500, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-1.7587], grad_fn=<RsubBackward1>), epsilon: 0.14728809893131256
# 55: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2504]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2496], grad_fn=<RsubBackward1>), epsilon: 0.1476045399904251
# 56: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2780]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2220], grad_fn=<RsubBackward1>), epsilon: 0.1478460133075714
# 57: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3141]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1859], grad_fn=<RsubBackward1>), epsilon: 0.147990420460701
# 58: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3523]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1477], grad_fn=<RsubBackward1>), epsilon: 0.1480383276939392
# 59: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3877]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3877], grad_fn=<RsubBackward1>), epsilon: 0.14889028668403625
# 60: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3744]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1256], grad_fn=<RsubBackward1>), epsilon: 0.1488872915506363
# 61: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3628]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1372], grad_fn=<RsubBackward1>), epsilon: 0.14890989661216736
# 62: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3533]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1467], grad_fn=<RsubBackward1>), epsilon: 0.14895451068878174
# 63: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3462]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1538], grad_fn=<RsubBackward1>), epsilon: 0.14901620149612427
# 64: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3415]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1585], grad_fn=<RsubBackward1>), epsilon: 0.1490892618894577
# 65: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3393]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1607], grad_fn=<RsubBackward1>), epsilon: 0.1491677314043045
# 66: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3394]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1606], grad_fn=<RsubBackward1>), epsilon: 0.14924584329128265
# 67: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3416]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1584], grad_fn=<RsubBackward1>), epsilon: 0.1493183970451355
# 68: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3457]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3457], grad_fn=<RsubBackward1>), epsilon: 0.15016907453536987
# 69: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3278]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1722], grad_fn=<RsubBackward1>), epsilon: 0.15027548372745514
# 70: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3125]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1875], grad_fn=<RsubBackward1>), epsilon: 0.15042155981063843
# 71: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3002]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1998], grad_fn=<RsubBackward1>), epsilon: 0.15060022473335266
# 72: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2911]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2089], grad_fn=<RsubBackward1>), epsilon: 0.1508033573627472
# 73: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2850]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2150], grad_fn=<RsubBackward1>), epsilon: 0.15102256834506989
# 74: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2820]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2180], grad_fn=<RsubBackward1>), epsilon: 0.1512497514486313
# 75: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2818]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2182], grad_fn=<RsubBackward1>), epsilon: 0.15147733688354492
# 76: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2841]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2159], grad_fn=<RsubBackward1>), epsilon: 0.15169844031333923
# 77: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2887]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2113], grad_fn=<RsubBackward1>), epsilon: 0.15190698206424713
# 78: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2951]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2049], grad_fn=<RsubBackward1>), epsilon: 0.15209779143333435
# 79: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3032]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3032], grad_fn=<RsubBackward1>), epsilon: 0.15294569730758667
# 80: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2890]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2110], grad_fn=<RsubBackward1>), epsilon: 0.15315216779708862
# 81: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2777]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2223], grad_fn=<RsubBackward1>), epsilon: 0.1533888280391693
# 82: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2696]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2304], grad_fn=<RsubBackward1>), epsilon: 0.15364739298820496
# 83: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2643]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2357], grad_fn=<RsubBackward1>), epsilon: 0.15391987562179565
# 84: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2618]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2382], grad_fn=<RsubBackward1>), epsilon: 0.15419882535934448
# 85: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2619]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2381], grad_fn=<RsubBackward1>), epsilon: 0.15447743237018585
# 86: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2642]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2358], grad_fn=<RsubBackward1>), epsilon: 0.15474949777126312
# 87: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2685]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2315], grad_fn=<RsubBackward1>), epsilon: 0.15500950813293457
# 88: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2747]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2253], grad_fn=<RsubBackward1>), epsilon: 0.1552525907754898
# 89: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2824]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2176], grad_fn=<RsubBackward1>), epsilon: 0.15547461807727814
# 90: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2913]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2087], grad_fn=<RsubBackward1>), epsilon: 0.15567225217819214
# 91: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3012]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1988], grad_fn=<RsubBackward1>), epsilon: 0.1558430790901184
# 92: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3118]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.3118], grad_fn=<RsubBackward1>), epsilon: 0.15668722987174988
# 93: dp: tensor([[0.2500, 0.2500, 0.2504, 0.3025]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.1975], grad_fn=<RsubBackward1>), epsilon: 0.15685364603996277
# 94: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2955]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2045], grad_fn=<RsubBackward1>), epsilon: 0.1570386439561844
# 95: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2907]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2093], grad_fn=<RsubBackward1>), epsilon: 0.1572362184524536
# 96: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2881]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2119], grad_fn=<RsubBackward1>), epsilon: 0.15744060277938843
# 97: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2875]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2125], grad_fn=<RsubBackward1>), epsilon: 0.15764640271663666
# 98: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2888]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([0.2112], grad_fn=<RsubBackward1>), epsilon: 0.15784868597984314
# 99: dp: tensor([[0.2500, 0.2500, 0.2504, 0.2916]], grad_fn=<MulBackward0>), arm_chosen:3, TD error: tensor([-2.2916], grad_fn=<RsubBackward1>), epsilon: 0.15869084000587463

# %% [markdown]
# ## Analysis

# %%
A_picks = avg_counts[0]
B_picks = avg_counts[1]
C_picks = avg_counts[2]
D_picks = avg_counts[3]

Avg_A_picks = torch.mean(A_picks, dim = 0)
Avg_B_picks = torch.mean(B_picks, dim = 0)
Avg_C_picks = torch.mean(C_picks, dim = 0)
Avg_D_picks = torch.mean(D_picks, dim = 0)

IGT_score = torch.mean(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0).squeeze().numpy()
IGT_dev = torch.std(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0)/torch.sqrt(torch.tensor(EPOCHS, dtype = torch.float32))
IGT_dev = IGT_dev.squeeze().numpy()

print(f'IGT score: {IGT_score} with SE of {IGT_dev}')
# Out:
# IGT score: [1.28 3.   4.4  4.78 5.32] with SE of [1.7109321 1.7801373 1.6812694 1.5103401 1.461484 ]

# %%
A_picks = avg_counts[0]
B_picks = avg_counts[1]
C_picks = avg_counts[2]
D_picks = avg_counts[3]

Avg_A_picks = torch.mean(A_picks, dim = 0)
Avg_B_picks = torch.mean(B_picks, dim = 0)
Avg_C_picks = torch.mean(C_picks, dim = 0)
Avg_D_picks = torch.mean(D_picks, dim = 0)

IP_A = torch.mean(ip_monitor[0], dim = 0).detach().numpy()
IP_B = torch.mean(ip_monitor[1], dim = 0).detach().numpy()
IP_C = torch.mean(ip_monitor[2], dim = 0).detach().numpy()
IP_D = torch.mean(ip_monitor[3], dim = 0).detach().numpy()

DP_A = torch.mean(dp_monitor[0], dim = 0).detach().numpy()
DP_B = torch.mean(dp_monitor[1], dim = 0).detach().numpy()
DP_C = torch.mean(dp_monitor[2], dim = 0).detach().numpy()
DP_D = torch.mean(dp_monitor[3], dim = 0).detach().numpy()

IGT_score = torch.mean(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0)
IGT_dev = torch.std(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0)/torch.sqrt(torch.tensor(EPOCHS, dtype = torch.float32))

IP_all = np.array([IP_A[:,0],IP_B[:,0],IP_C[:,0],IP_D[:,0]])
IP_Var = np.std(IP_all,axis = 0 )

# %% [markdown]
# ## Results

# %%
random_pick = np.random.choice(np.arange(EPOCHS), size = 9)

plt.figure(figsize=(10,8))
for i in range(9):
    plt.subplot(3,3,i+1)
    colors = np.where(np.isin(arm_chosen_monitor[random_pick[i]],[0,1]), 'r', 'g')
    plt.scatter(np.arange(TRAILS), arm_chosen_monitor[random_pick[i]], c = colors, s = 10)
    plt.ylim(-1,4)
plt.xlabel('trails', fontsize = 9)
# Out:
# Text(0.5, 0, 'trails')

# %%
BINS = np.arange(5) + 1

plt.figure(figsize=(10, 3))
font = {'family': 'Arial', 'size': 11}

plt.subplot(131)
plt.plot(np.arange(100), IP_A, label='A', color='#1f77b4', linewidth=2)
plt.plot(np.arange(100), IP_B, label='B', color='#ff7f0e', linewidth=2)
plt.plot(np.arange(100), IP_C, label='C', color='#2ca02c', linewidth=2)
plt.plot(np.arange(100), IP_D, label='D', color='#8c564b', linewidth=2)
plt.xlabel('Trials', **font)
plt.title('Avg IP with Trials', **font)
plt.legend(loc='upper right', fontsize=10)

plt.subplot(132)
plt.plot(BINS, Avg_A_picks, label='A', color='#1f77b4', marker='o', markersize=7, linewidth=2)
plt.plot(BINS, Avg_B_picks, label='B', color='#ff7f0e', marker='s', markersize=7, linewidth=2)
plt.plot(BINS, Avg_C_picks, label='C', color='#2ca02c', marker='D', markersize=7, linewidth=2)
plt.plot(BINS, Avg_D_picks, label='D', color='#8c564b', marker='^', markersize=7, linewidth=2)
plt.title('Avg Card Picks with Trials', **font)
plt.legend(loc='upper right', fontsize=10)

plt.subplot(133)
plt.bar(BINS, IGT_score.reshape(5), color='#1f77b4', alpha=0.7)
plt.errorbar(BINS, IGT_score.reshape(5), yerr=IGT_dev.reshape(5), fmt='o', color='black', capsize=5)
plt.title('IGT Score', **font)
plt.xlabel('BINS', **font)
plt.ylabel('IGT Score', **font)

plt.tight_layout()

# %%
IGT_expt= np.array([-1.83,1.5,2.6,4.59,3.9])
IGT_Simulated = IGT_score.reshape(5)

# %%
# Plotting bar for IGT
plt.figure(figsize=(7,5))
plt.bar(BINS, IGT_Simulated, width=0.3, color = 'red', label = 'simulated')
plt.bar(BINS+0.3, IGT_expt, width=0.3, color = 'green', label = 'Experimental')
plt.ylim(-10,10)
plt.title(f'IGT score')
plt.xlabel('BINS')
plt.ylabel('IGT Score')
plt.legend()
plt.tight_layout()

# %% [markdown]
# ## Statistical testing

# %%
mean_sim = IGT_score.squeeze().detach().numpy()
mean_expt = IGT_expt
std_sim = torch.std(torch.add(C_picks, D_picks) - torch.add(A_picks, B_picks), dim = 0).squeeze().detach().numpy()
std_expt = std_sim
n_sim = EPOCHS
n_expt = 20

# %%
def compare_multiple_pairs(mean_exp, std_exp, n_exp, mean_sim, std_sim, n_sim):
    results = []

    for i in range(len(mean_exp)):
        m1, s1 = mean_exp[i], std_exp[i]
        m2, s2 = mean_sim[i], std_sim[i]

        # Standard error
        se = math.sqrt((s1**2)/n_exp + (s2**2)/n_sim)

        # t-statistic
        t_stat = (m1 - m2) / se

        # Degrees of freedom (Welch-Satterthwaite)
        df_num = (s1**2/n_exp + s2**2/n_sim)**2
        df_den = ((s1**2/n_exp)**2 / (n_exp - 1)) + ((s2**2/n_sim)**2 / (n_sim - 1))
        df = df_num / df_den

        # Two-tailed p-value
        p_val = 2 * (1 - t.cdf(abs(t_stat), df))
        conclusion = "Statistically different" if p_val < 0.05 else "Not statistically different"

        results.append({
            "Index": i+1,
            "Exp Mean": m1,
            "Sim Mean": m2,
            "t-stat": round(t_stat, 3),
            "p-value": round(p_val, 4),
            "Significant": p_val < 0.05,
            "Conclusion": conclusion

        })

    return pd.DataFrame(results)

# Run comparison
df_results_IGT_mean = compare_multiple_pairs(mean_expt, std_expt, n_expt, mean_sim, std_sim, n_sim)

# Show results
# import ace_tools as tools; tools.display_dataframe_to_user(name="Significance Comparison Results", dataframe=df_results)

# %%
df_results_IGT_mean
# Out:
#    Index  Exp Mean  Sim Mean  t-stat  p-value  Significant  \
# 0      1     -1.83      1.28  -0.742   0.4644        False
# 1      2      1.50      3.00  -0.344   0.7335        False
# 2      3      2.60      4.40  -0.437   0.6655        False
# 3      4      4.59      4.78  -0.051   0.9594        False
# 4      5      3.90      5.32  -0.397   0.6947        False
#
#                     Conclusion
# 0  Not statistically different
# 1  Not statistically different
# 2  Not statistically different
# 3  Not statistically different
# 4  Not statistically different
