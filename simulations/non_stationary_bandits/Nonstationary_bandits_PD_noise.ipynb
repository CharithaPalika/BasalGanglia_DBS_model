# %%
# import numpy as np
# from matplotlib import pyplot as plt
# import pandas as pd
# import torch.nn as nn
# import torch
# from tqdm.autonotebook import tqdm
# import seaborn as sns
# from Environments.NonStationaryBandits import NonStationaryEnv
# from BasalGanglia.train import train
# import pickle

import os, sys

# Root project
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))

if project_root not in sys.path:
    sys.path.append(project_root)

print("Project root added to sys.path:", project_root)


import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import torch.nn as nn
import torch
import random
from tqdm.autonotebook import tqdm
import seaborn as sns
from envs import NonStationaryEnv
from basal_ganglia import train
import pickle
# Out:
# C:\Users\chari\AppData\Local\Temp\ipykernel_31848\1069778861.py:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %% [markdown]
# ## Hyper Params

# %%
TRAILS = 150
EPOCHS = 20
BINS = 15
LR = 0.1 #0.005 #0.0025
NUM_ARMS = 3
SCALING_FACTOR = 100
TIME_STAMP_CHANGE = 75
BIN_SIZE = TRAILS//BINS
BIN_CHANGE = TIME_STAMP_CHANGE // BIN_SIZE

# %% [markdown]
# ## TRAINING LOOP

# %%
env = NonStationaryEnv(
    num_arms = NUM_ARMS, 
    mean_reward = np.array([20,40,30])/SCALING_FACTOR, 
    std = np.array([5,5,5])/SCALING_FACTOR, 
    mean_rew_change = np.array([10,35,40])/SCALING_FACTOR, 
    std_change = np.array([5,5,5])/SCALING_FACTOR, 
    time_stamp_change = TIME_STAMP_CHANGE)

BEST_ARM_BEFORE = 1
BEST_ARM_AFTER = 2

BEST_ARM = torch.zeros((EPOCHS,TRAILS), dtype=int)
BEST_ARM[:,:TIME_STAMP_CHANGE] = BEST_ARM_BEFORE
BEST_ARM[:,TIME_STAMP_CHANGE:] = BEST_ARM_AFTER

# %%
reward_monitor, arm_chosen_monitor, avg_counts,ip_monitor, dp_monitor,ep_monitor= train(env, 
                                                      trails = TRAILS, 
                                                      epochs = EPOCHS, 
                                                      lr = LR, 
                                                      bins = BINS,
                                                      STN_data = None, #'rossler',
                                                      d1_amp=0.7,
                                                      d2_amp=0.01, 
                                                      gpi_threshold=0.3,
                                                      max_gpi_iters=50,
                                                      del_lim=None, train_IP = False, 
                                                      del_med = None, printing = True,
                                                      gpi_mean= 1, ep_0 = 0.096,
                                                      alpha_ep = 0.0,
                                                      eta_ep = 0.1,
                                                      baseline_ep = 0.0)
# Out:
# 0: dp: tensor([[0.3504, 0.3504, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1812], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 1: dp: tensor([[0.3500, 0.3504, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.1363], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 2: dp: tensor([[0.3500, 0.3829, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.0847], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 3: dp: tensor([[0.3500, 0.4232, 0.3505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.0330], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 4: dp: tensor([[0.3500, 0.4657, 0.3505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.0363], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 5: dp: tensor([[0.3500, 0.4901, 0.3505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.0360], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 6: dp: tensor([[0.3500, 0.5012, 0.3505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.1394], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 7: dp: tensor([[0.3500, 0.4910, 0.3505]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.2375], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 8: dp: tensor([[0.3500, 0.4664, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.0827], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 9: dp: tensor([[0.3500, 0.4471, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.0286], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 10: dp: tensor([[0.3500, 0.4287, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.0306], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 11: dp: tensor([[0.3500, 0.4138, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.0716], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 12: dp: tensor([[0.3500, 0.3961, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([-0.0278], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 13: dp: tensor([[0.3500, 0.3782, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.0031], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 14: dp: tensor([[0.3500, 0.3620, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.0128], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 15: dp: tensor([[0.3500, 0.3536, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:1, TD error: tensor([0.0389], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 16: dp: tensor([[0.3500, 0.3500, 0.3504]], grad_fn=<MulBackward0>), arm_chosen:2, TD error: tensor([-0.0263], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 17: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1207], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 18: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1688], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 19: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1767], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 20: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1429], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 21: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2290], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 22: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0785], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 23: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1141], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 24: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1851], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 25: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0758], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 26: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1305], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 27: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1502], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 28: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1530], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 29: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1460], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 30: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1897], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 31: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1231], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 32: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0723], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 33: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1168], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 34: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2691], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
#
grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 58: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1487], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 59: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1593], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 60: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0913], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 61: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1222], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 62: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0376], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 63: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1630], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 64: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1937], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 65: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0666], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 66: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2001], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 67: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0671], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 68: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1749], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 69: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1573], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 70: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1662], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 71: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1892], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 72: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0719], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 73: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.0844], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 74: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1817], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 75: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2546], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 76: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3447], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 77: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2919], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 78: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2357], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 79: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2783], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 80: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1941], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 81: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2635], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 82: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3180], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 83: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1653], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 84: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1977], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 85: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2178], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 86: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2326], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 87: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2483], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 88: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3541], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 89: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2637], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 90: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2955], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 91: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1986], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 92: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2812], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 93: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2331], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 94: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2423], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 95: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2470], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 96: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3278], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 97: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2095], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 98: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2331], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 99: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2379], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 100: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2804], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 101: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3369], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 102: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3573], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 103: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3115], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 104: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2986], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 105: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1594], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 106: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1630], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 107: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3740], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 108: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3047], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 109: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2447], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 110: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2863], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 111: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2599], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 112: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1572], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 113: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2083], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 114: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1759], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 115: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2021], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 116: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3361], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 117: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2050], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 118: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2658], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 119: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2017], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 120: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2155], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 121: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2376], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 122: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3448], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 123: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2428], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 124: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2573], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 125: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3213], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 126: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2533], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 127: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3156], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 128: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1891], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 129: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2382], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 130: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2377], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 131: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2522], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 132: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2710], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 133: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2542], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 134: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2907], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 135: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2354], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 136: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2574], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 137: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2725], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 138: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2760], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 139: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1455], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 140: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3951], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 141: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2686], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 142: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2164], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 143: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2705], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 144: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2245], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 145: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2519], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 146: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2467], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 147: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.1932], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 148: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.3459], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503
# 149: dp: tensor([[0.3500, 0.3500, 0.3500]], grad_fn=<MulBackward0>), arm_chosen:0, TD error: tensor([-0.2390], grad_fn=<RsubBackward1>), epsilon: 0.09600000083446503

# %% [markdown]
# ## ANALYSIS

# %%
mean_picks = {key: torch.mean(avg_counts[key], dim = 0) for key in list(avg_counts.keys())}
IP_avg = {key: torch.mean(ip_monitor[key], dim =0).detach().numpy() for key in list(ip_monitor.keys())}
DP_avg = {key: torch.mean(dp_monitor[key], dim =0).detach().numpy() for key in list(dp_monitor.keys())}
IP_var = np.std(np.stack(list(IP_avg.values()), axis=0),axis = 0)[:,0]
arm_chosen_monitor = arm_chosen_monitor.to(torch.int)
# Computing Accuracy
accuracy_percentages = torch.zeros((EPOCHS, BINS))

for i in range(BINS):
    start, end = i * BIN_SIZE, (i + 1) * BIN_SIZE
    correct_choices = torch.sum(arm_chosen_monitor[:, start:end] == BEST_ARM[:,start:end], axis = 1)
    accuracy_percentages[:, i] = (correct_choices / BIN_SIZE) * 100

accuracy_per_bin = torch.mean(accuracy_percentages,axis = 0)

# %%
random_epochs = np.random.choice(np.arange(EPOCHS), size = 9)
i = 1
plt.figure(figsize=(15,12))
for e in random_epochs:
    plt.subplot(3,3,i)
    colors = np.where(np.isin(arm_chosen_monitor[e],[0,1]), 'r', 'g')
    plt.scatter(np.arange(TRAILS), arm_chosen_monitor[e], c = colors)
    plt.ylim(-1,4)
    plt.xlabel('trails', fontsize = 9)
    i+=1

plt.suptitle('Card picks in each epoch')
plt.tight_layout()

# %%
BIN = np.arange(BINS)+1
color_map = ['r', 'r', 'g', 'g']
plt.figure(figsize=(15,14))
plt.subplot(321)
for i in DP_avg.keys():
    plt.plot(np.arange(TRAILS), DP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=2, label='Reward change')
plt.xlabel('trails')
plt.title('Avg DP with trails')
plt.legend(loc = 'upper right')

plt.subplot(322)
for i in DP_avg.keys():
    plt.plot(np.arange(TRAILS), IP_avg[i], label = i)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=2, label='Reward change')
plt.xlabel('trails')
plt.title('Avg IP with trails')
plt.legend(loc = 'upper right')

plt.subplot(323)
for i in mean_picks.keys():
    plt.plot(BIN,mean_picks[i], label = i, marker = '.', markersize = 8)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=2, label='Reward change')
plt.title('Avg card picks with trails')
plt.xlabel('bins')
plt.legend(loc = 'upper right')


plt.subplot(324)
mean_rew = torch.mean(reward_monitor, 0)
std_rew = torch.std(reward_monitor,0)
plt.plot(np.arange(TRAILS), mean_rew)
plt.fill_between(np.arange(TRAILS), mean_rew - std_rew, mean_rew+std_rew, alpha = 0.5)
plt.axvline(x=TIME_STAMP_CHANGE, color='black', linestyle='--', linewidth=2, label='Reward change')
plt.title('Mean reward')
plt.xlabel('trails')

# plt.subplot(325)
# plt.plot(IP_var)
# plt.title('IP variance')
# plt.xlabel('trails')

plt.subplot(325)
plt.plot(BIN, accuracy_per_bin, marker = '.', markersize = 10)
plt.axvline(x=BIN_CHANGE, color='black', linestyle='--', linewidth=2, label='Reward change')
plt.title('Accuracy')
plt.ylim(0,100)
plt.xlabel('bins')
plt.legend(loc = 'upper right')
plt.tight_layout()

# %%
random_epochs = np.random.choice(np.arange(EPOCHS), size = 6)
i = 1
plt.figure(figsize=(15,8))
for e in random_epochs:
    plt.subplot(2,3,i)
    plt.plot(np.arange(TRAILS), ep_monitor[e])
    i+=1
    plt.xlabel('trails', fontsize = 9)
    plt.ylabel('epsilon', fontsize = 9)

plt.suptitle('Epsilon trend accross each epoch')
plt.tight_layout()

# %%
plt.figure(figsize=(5,4))
plt.plot(np.arange(TRAILS), ep_monitor[2])
plt.axvline(x=TIME_STAMP_CHANGE, color='red', linestyle='--', linewidth=2, label='Reward change')
plt.xlabel('trails', fontsize = 9)
plt.ylabel('epsilon', fontsize = 9)
plt.legend(loc = 'upper right')
plt.title('Epsilon trend')
plt.tight_layout()
plt.figure(figsize=(5,4))
colors = np.where(np.isin(arm_chosen_monitor[2],[0,1]), 'r', 'g')
plt.scatter(np.arange(TRAILS), arm_chosen_monitor[2], c = colors)
plt.ylim(-1,4)
plt.xlabel('trails', fontsize = 9)
plt.title('Card picks in epoch 2')
plt.tight_layout()

# %%
# Plot: Probability/Percentage of Picking the Best Arm Across Bins
plt.figure(figsize=(8,5))
plt.plot(BIN, accuracy_per_bin, marker='o', label='Best Arm Picked (%)')
plt.axvline(BIN_CHANGE+1, color='red', linestyle='--', linewidth=2, label='Reward Change')
plt.xlabel('Bin')
plt.ylabel('Percentage of Best Arm Picks')
plt.title('Probability of Picking Best Arm Across Bins')
plt.ylim(0, 105)
plt.legend()
plt.tight_layout()
plt.show()
print(accuracy_per_bin)
# Out:
# tensor([82.0000, 81.5000, 71.5000, 66.5000, 60.0000, 57.0000, 55.0000, 25.5000,
#          5.5000,  3.5000,  0.0000,  2.5000,  5.0000,  9.0000, 10.0000])

# %%
# saving pickle data
data = {'accuracy': accuracy_percentages.numpy(),
        'reward_monitor': reward_monitor.numpy(),
        'epsilon_monitor': ep_monitor.numpy(),
        'arm_chosen_monitor': arm_chosen_monitor.numpy()
        }

with open('non_stationary_bandit_data_pd.pkl', 'wb') as f:
    pickle.dump(data, f)
